# %% [markdown]
# # SVM & Naive Bayes   Assignment

# %% [markdown]
# 1.  What is a Support Vector Machine (SVM), and how does it work?
#
# Ans:A Support Vector Machine (SVM) is a supervised machine learning algorithm used for classification and regression. It works by finding the optimal hyperplane that separates data points into different classes, maximizing the margin between them. This margin is defined by "support vectors," which are the data points closest to the hyperplane. SVMs can handle both linear and non-linear data by mapping it into a higher-dimensional space using kernel functions.
#
# Here's a breakdown of how SVMs work:
#
# 1. Finding the Optimal Hyperplane:
#
#  - In a multi-dimensional space, a hyperplane acts as a decision boundary.
#
#  - SVM aims to find the hyperplane that best separates the different classes of data points with the widest possible margin.
#
#  - The margin is the distance between the hyperplane and the closest data points (support vectors).
#
#  - Maximizing the margin helps in better generalization of the model, meaning it performs well on unseen data.
#
# 2. Support Vectors:
#
#  - These are the data points that lie closest to the hyperplane and influence its position.
#
#  - SVM focuses on these critical points to define the decision boundary, ignoring other data points.
#
# 3. Handling Non-linear Data:
#
#  - For data that is not linearly separable (cannot be separated by a straight line or hyperplane), SVM uses kernel functions to map the data into a higher-dimensional space where it becomes linearly separable.
#
#  - Common kernel functions include polynomial kernels, radial basis function (RBF) kernels, and sigmoid kernels.
#
# 4. Types of SVM:
#
#  - Linear SVM: Used for linearly separable data.
#
#  - Non-linear SVM: Uses kernel functions to handle non-linearly separable data.
#
#  - Support Vector Regression (SVR): Used for regression problems, predicting continuous values rather than discrete classes.
#
# 5. Applications:
#
#  - Classification: Spam detection, image classification, fraud detection.
#
#  - Regression: Predicting house prices, stock prices.
#
# SVMs are powerful classifiers that excel at finding optimal decision boundaries, especially in complex datasets, by strategically using support vectors and kernel functions.
#
#
# How SVM Works
#
# 1. Linear Separation
#
# Imagine you have data points in 2D belonging to two classes (say, circles and triangles).
#
# An SVM tries to find a line (in 2D), a plane (in 3D), or a hyperplane (in higher dimensions) that separates the two classes with the largest possible margin.
#
# Mathematically, the hyperplane is defined as:
#
# 𝑤
# ⋅
# 𝑥
# +
# 𝑏
# =
# 0
# w⋅x+b=0
#
# where:
#
# 𝑤
# w is the weight vector (orientation of the hyperplane),
#
# 𝑏
# b is the bias (offset),
#
# 𝑥
# x is the input vector.
#
# 2. Maximizing the Margin
#
# The margin is the distance from the hyperplane to the nearest data points.
#
# SVM optimizes so that this margin is as wide as possible, making the classifier more robust.
#
# 3. Non-Linearly Separable Data
#
# Real-world data is often not linearly separable.
#
# SVM uses a technique called the kernel trick, which maps the input data into a higher-dimensional feature space where it becomes linearly separable.
#
#  Common kernels:
#
# Linear: no transformation.
#
# Polynomial: handles curved boundaries.
#
# Radial Basis Function (RBF): popular for complex boundaries.
#
# Sigmoid: behaves like a neural network.
#
#  4. Soft Margin (Regularization)
#
# To handle noise and overlapping classes, SVM introduces a penalty parameter
# 𝐶
# C.
#
# A small
# 𝐶
# C: allows more misclassifications → softer margin → prevents overfitting.
#
# A large
# 𝐶
# C: tries to classify everything correctly → harder margin → risk of overfitting.
#
#
#  -- Advantages
#
#  - Works well in high-dimensional spaces (e.g., text classification, bioinformatics).
#
#  - Effective when classes are well-separated.
#
#  - Only relies on support vectors, so it’s memory efficient.
#
# --  Limitations
#
#  - Computationally expensive for very large datasets.
#
#  - Performance depends heavily on choice of kernel and hyperparameters.
#
#  - Not as effective when classes overlap significantly.

# %% [markdown]
# 2. Explain the difference between Hard Margin and Soft Margin SVM?
#
# Ans:In Support Vector Machines (SVM), hard margin SVM aims to find a hyperplane that perfectly separates data points into different classes with no errors. Soft margin SVM relaxes this constraint by allowing some data points to be misclassified, making it more flexible and robust for datasets that aren't perfectly linearly separable or contain outliers.
#
# Here's a more detailed explanation:
# 1. Hard Margin SVM:
#
#  - Goal:
# Perfectly separates data into classes with no misclassifications.
#
#  - Suitable for:
# Datasets that are linearly separable, meaning a straight line (or hyperplane in higher dimensions) can perfectly divide the data.
#
#  - Sensitive to:
# Outliers and noise in the data, as a single outlier can significantly impact the optimal hyperplane.
#
#  - Mathematical Formulation:
# Maximizes the margin (distance between the hyperplane and the closest data points) while ensuring all data points are correctly classified.
#
# --Advantages of Hard Margin
#
#  - Guaranteed Separation: Hard margin SVM ensures that the classes are perfectly separated, leading to optimal generalization performance when the training data is linearly separable.
#
#  - Simplicity: The optimization problem in hard margin SVM is well-defined and has a unique solution, making it computationally efficient.
#
# --Disadvantages of Hard Margin
#
#  - Sensitivity to Outliers: Hard margin SVM is highly sensitive to outliers or noisy data points. Even a single mislabeled point can significantly affect the position of the decision boundary and lead to poor generalization on unseen data.
#
#  - Not Suitable for Non-linear Data: When the data is not linearly separable, hard margin SVM fails to find a valid solution, rendering it impractical for many real-world datasets.
#
# 2. Soft Margin SVM:
#
#  - Goal: Allows for some misclassifications to improve generalization and robustness.
#
#  - Suitable for: Datasets that are not perfectly linearly separable or contain outliers.
#
#  - More Flexible: Introduces "slack variables" to allow data points to be on the wrong side of the margin or even misclassified.
#
#  - Parameter C: Controls the trade-off between maximizing the margin and minimizing misclassifications. A higher C value penalizes misclassifications more heavily, leading to a smaller margin, while a lower C value allows for more misclassifications and a wider margin.
#
#  - Robustness: More robust to outliers and noise compared to hard margin SVM.
#
#
#
#
#
# -- Advantages of Soft Margin SVM
#
#  - Robustness to Outliers: Soft margin SVM can handle outliers or noisy data more effectively by allowing for some misclassifications. This results in a more robust decision boundary that generalizes better to unseen data.
#
#  - Applicability to Non-linear Data: Unlike hard margin SVM, soft margin SVM can handle non-linearly separable data by implicitly mapping it to a higher-dimensional space using kernel functions. This enables SVM to capture complex decision boundaries.
#
#
# --Disadvantages of Soft Margin SVM
#
#  - Need for Parameter Tuning: The performance of soft margin SVM heavily depends on the choice of the regularization parameter C. Selecting an appropriate value for C requires careful tuning, which can be time-consuming and computationally expensive, especially for large datasets.
#
#  - Potential Overfitting: In cases where the value of C is too large, soft margin SVM may overfit the training data by allowing too many margin violations
#
#
#
#  --Key Difference in Simple Terms
#
#  - Hard Margin SVM: No mistakes allowed. Perfect separation only.
#
#  - Soft Margin SVM: Some mistakes allowed. Tries to balance margin size with classification errors.
#
#
#
#
#  --Analogy:
#
# Think of drawing a boundary between two groups of students in a playground:
#
#  - Hard margin = rope boundary where no student can cross → strict but unrealistic if students move around.
#
#  - Soft margin = flexible rope where a few students may cross slightly, but overall separation is maintained → more practical in real life.

# %% [markdown]
# 3. What is the Kernel Trick in SVM? Give one example of a kernel and
# explain its use case.?
#
# Ans: The Kernel Trick in Support Vector Machines (SVMs) is a technique that allows SVMs to find non-linear decision boundaries by implicitly mapping data into a higher-dimensional feature space without explicitly calculating the coordinates in that space. This is achieved by using kernel functions, which compute the dot product between data points in the higher-dimensional space directly from their original lower-dimensional representation. This avoids the computational cost and complexity of explicitly transforming the data.
#
#  - Many real-world datasets are not linearly separable in their original feature space.
#
#  - Instead of manually transforming data into higher dimensions, the kernel trick lets us implicitly map data into a higher-dimensional feature space without actually computing the transformation.
#
#  - This makes it possible to find a linear separating hyperplane in that higher-dimensional space, which corresponds to a non-linear boundary in the original space.
#
# ---How it Works
#
#  - In SVM, we need to compute dot products between feature vectors.
#
#  - If we apply a mapping function
# 𝜙
# (
# 𝑥
# )
# ϕ(x) to transform the data into higher dimensions, the dot product becomes:
#
# 𝐾
# (
# 𝑥
# 𝑖
# ,
# 𝑥
# 𝑗
# )
# =
# 𝜙
# (
# 𝑥
# 𝑖
# )
# ⋅
# 𝜙
# (
# 𝑥
# 𝑗
# )
# K(x
# i
# 	​
#
# ,x
# j
# 	​
#
# )=ϕ(x
# i
# 	​
#
# )⋅ϕ(x
# j
# 	​
#
# )
#
# Instead of computing
# 𝜙
# (
# 𝑥
# )
# ϕ(x) explicitly, we use a kernel function
# 𝐾
# (
# 𝑥
# 𝑖
# ,
# 𝑥
# 𝑗
# )
# K(x
# i
# 	​
#
# ,x
# j
# 	​
#
# ) that directly computes the dot product in the higher-dimensional space.
#
#  - This avoids heavy computation and allows SVM to work efficiently in very high-dimensional (even infinite-dimensional) spaces.
#
#  - Example: Radial Basis Function (RBF) Kernel
#
#  - The RBF kernel is one of the most widely used kernels.
#
# 𝐾
# (
# 𝑥
# 𝑖
# ,
# 𝑥
# 𝑗
# )
# =
# exp
# ⁡
# (
# −
# 𝛾
# ∥
# 𝑥
# 𝑖
# −
# 𝑥
# 𝑗
# ∥
# 2
# )
# K(x
# i
# 	​
#
# ,x
# j
# 	​
#
# )=exp(−γ∥x
# i
# 	​
#
# −x
# j
# 	​
#
# ∥
# 2
# )
#
# where:
#
# ∥
# 𝑥
# 𝑖
# −
# 𝑥
# 𝑗
# ∥
# ∥x
# i
# 	​
#
# −x
# j
# 	​
#
# ∥ = distance between two data points,
#
# 𝛾
# γ = parameter controlling how far the influence of a single training point reaches.
#
# ---Use Case of RBF Kernel
#
#  - Works well when data is non-linearly separable.
#
#  - Example: Classifying whether a tumor is benign or malignant based on medical measurements. The decision boundary may be highly curved, and a linear SVM would fail.
#
#  - The RBF kernel maps the data into a higher-dimensional space where the classes become separable with a non-linear boundary.
#
#  - The Kernel Trick allows SVM to handle non-linear classification efficiently.
#
#  - The RBF kernel is particularly powerful for complex decision boundaries (e.g., image classification, medical diagnosis, fraud detection).
#
#   - Use Case: The RBF kernel is widely used when the relationship between data points is non-linear and complex, and there is no clear prior knowledge about the structure of the data. For instance, in image classification, where pixel values might not be linearly separable, the RBF kernel can effectively capture intricate patterns by considering the similarity between images based on their proximity in the feature space. This allows the SVM to create a flexible, non-linear decision boundary that can accurately classify images.

# %% [markdown]
# 4.  What is a Naïve Bayes Classifier, and why is it called “naïve”?
#
# Ans:What is a Naïve Bayes Classifier
#
# Naïve Bayes is a probabilistic supervised learning algorithm based on Bayes’ Theorem.
#
# It is mainly used for classification tasks (e.g., spam detection, sentiment analysis, text categorization).
#
# -- Bayes’ Theorem:
# 𝑃
# (
# 𝑌
# ∣
# 𝑋
# )
# =
# 𝑃
# (
# 𝑋
# ∣
# 𝑌
# )
# ⋅
# 𝑃
# (
# 𝑌
# )
# 𝑃
# (
# 𝑋
# )
# P(Y∣X)=
# P(X)
# P(X∣Y)⋅P(Y)
# 	​
#
#
# Where:
#
# 𝑃
# (
# 𝑌
# ∣
# 𝑋
# )
# P(Y∣X) = probability of class
# 𝑌
# Y given features
# 𝑋
# X (posterior probability).
#
# 𝑃
# (
# 𝑋
# ∣
# 𝑌
# )
# P(X∣Y) = probability of observing features
# 𝑋
# X given class
# 𝑌
# Y (likelihood).
#
# 𝑃
# (
# 𝑌
# )
# P(Y) = prior probability of class
# 𝑌
# Y.
#
# 𝑃
# (
# 𝑋
# )
# P(X) = prior probability of features (normalization term).
#
# Naïve Bayes uses this to predict the most likely class for a given input.
#
# --- Why is it called “Naïve”
#
#  - It makes a strong simplifying assumption:
#
#  - All features are conditionally independent given the class.
#
#  - In reality, features are often correlated (e.g., in spam detection, words like “offer” and “free” are related).
#
#  - But the assumption makes the computation much simpler and surprisingly still works very well in practice.
#
#
#  - The independence assumption is often unrealistic in real-world datasets.
#
#  - For example, in text classification, the presence of one word might make another word more likely to appear, but a Naive Bayes classifier would treat them as independent.
#
#  - Despite this simplification, Naive Bayes classifiers can be surprisingly effective, particularly in text classification, due to their simplicity and speed.
#
# --- Example
#
#  - Suppose you want to classify an email as spam or not spam.
#
#  - Features = words in the email (e.g., “win”, “free”, “offer”).
#
#  - Naïve Bayes assumes each word contributes independently to whether the email is spam.
#
#  - It computes probabilities for spam and not spam, then picks the class with the highest probability.
#
# -- Advantages
#
#  - Very fast and scalable (works well for large datasets).
#
#  - Performs well in text classification and document categorization.
#
#  - Requires small amounts of training data.
#
#
# --Limitations
#
#  - The “naïve” assumption of feature independence is rarely true in real data.
#
#  - If features are highly correlated, accuracy may drop.
#
#  - Can struggle with numerical features unless modeled properly (Gaussian Naïve Bayes is used for continuous data).
#
#
#
# Naïve Bayes is a probabilistic classifier based on Bayes’ Theorem. It’s called naïve because it assumes that all features are independent given the class — an assumption that simplifies computation but is often unrealistic.

# %% [markdown]
# 5. Describe the Gaussian, Multinomial, and Bernoulli Naïve Bayes variants.
# When would you use each one?
#
# Ans:1. Gaussian Naïve Bayes
#
#  - Assumption:
# Features follow a normal (Gaussian) distribution within each class.
#
#  - Mathematical Formulation:
# The likelihood is modeled as:
#
# 𝑃
# (
# 𝑥
# 𝑖
# ∣
# 𝑦
# )
# =
# 1
# 2
# 𝜋
# 𝜎
# 𝑦
# 2
# exp
# ⁡
# (
# −
# (
# 𝑥
# 𝑖
# −
# 𝜇
# 𝑦
# )
# 2
# 2
# 𝜎
# 𝑦
# 2
# )
# P(x
# i
# 	​
#
# ∣y)=
# 2πσ
# y
# 2
# 	​
# 1
# 	​
#
# exp(−
# 2σ
# y
# 2
# 	​
#
# (x
# i
# 	​
#
# −μ
# y
# 	​
#
# )
# 2
# 	​
#
# )
#
# where
# 𝜇
# 𝑦
# μ
# y
# 	​
#
#  and
# 𝜎
# 𝑦
# σ
# y
# 	​
#
#  are mean and variance of feature
# 𝑥
# 𝑖
# x
# i
# 	​
#
#  for class
# 𝑦
# y.
#
#  - When to Use:
#
# For continuous features that are approximately normally distributed.
#
#  - Examples:
#
# Medical diagnosis (height, weight, blood pressure).
#
# Sensor data classification.
#
# Predicting species of flowers using measurements (like Iris dataset).
#
#  2. Multinomial Naïve Bayes
#
#  - Assumption:
# Features represent counts or frequencies (discrete values).
#
#  - Mathematical Formulation:
# The likelihood is:
#
# 𝑃
# (
# 𝑥
# ∣
# 𝑦
# )
# =
# (
# 𝑛
# !
# )
# 𝑥
# 1
# !
# 𝑥
# 2
# !
# …
# 𝑥
# 𝑛
# !
# ∏
# 𝑖
# =
# 1
# 𝑛
# 𝑝
# 𝑖
# ,
# 𝑦
# 𝑥
# 𝑖
# P(x∣y)=
# x
# 1
# 	​
#
# !x
# 2
# 	​
#
# !…x
# n
# 	​
#
# !
# (n!)
# 	​
#
# i=1
# ∏
# n
# 	​
#
# p
# i,y
# x
# i
# 	​
# where
# 𝑥
# 𝑖
# x
# i
# 	​
#
#  is the count of feature
# 𝑖
# i and
# 𝑝
# 𝑖
# ,
# 𝑦
# p
# i,y
# 	​
#
#  is the probability of feature
# 𝑖
# i in class
# 𝑦
# y.
#
#  - When to Use:
#
# For text classification, where features are word counts or term frequencies.
#
#  - Examples:
#
# Spam filtering (word counts in email).
#
# Document classification (news categorization, sentiment analysis).
#
# Topic modeling (bag-of-words representation).
#
#  3. Bernoulli Naïve Bayes
#
#  - Assumption:
# Features are binary variables (0 or 1 → presence or absence).
#
#  - Mathematical Formulation:
# Each feature is modeled with a Bernoulli distribution:
#
# 𝑃
# (
# 𝑥
# 𝑖
# ∣
# 𝑦
# )
# =
# 𝑝
# 𝑖
# ,
# 𝑦
# 𝑥
# 𝑖
# (
# 1
# −
# 𝑝
# 𝑖
# ,
# 𝑦
# )
# 1
# −
# 𝑥
# 𝑖
# P(x
# i
# 	​
#
# ∣y)=p
# i,y
# x
# i
# 	​
#
# (1−p
# i,y
# 	​
#
# )
# 1−x
# i
# 	​
#
# where
# 𝑝
# 𝑖
# ,
# 𝑦
# p
# i,y
# 	​
#
#  is the probability of feature
# 𝑖
# i occurring in class
# 𝑦
# y.
#
#  - When to Use:
#
# For binary features (yes/no, present/absent).
#
#  - Examples:
#
# Text classification using word presence/absence instead of counts.
#
# Document classification with binary bag-of-words.
#
# Medical diagnosis (symptom present = 1, absent = 0).

# %%
 # 6. #Dataset Info:
# You can use any suitable datasets like Iris, Breast Cancer, or Wine from
#sklearn.datasets or a CSV file you have.
#Question 6:   Write a Python program to:
#● Load the Iris dataset
#Train an SVM Classifier with a linear kernel
#Print the model's accuracy and support vectors.



# Import necessary libraries
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = datasets.load_iris()
X = iris.data      # Features
y = iris.target    # Target labels

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train an SVM Classifier with a linear kernel
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)

# Predict on the test set
y_pred = svm_model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print results
print("SVM Classifier with Linear Kernel")
print(f"Accuracy: {accuracy:.2f}")
print("Number of Support Vectors for each class:", svm_model.n_support_)
print("Support Vectors:\n", svm_model.support_vectors_)
# Out:
# SVM Classifier with Linear Kernel
# Accuracy: 1.00
# Number of Support Vectors for each class: [ 3 11 10]
# Support Vectors:
#  [[4.8 3.4 1.9 0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.5 2.3 1.3 0.3]
#  [5.6 3.  4.5 1.5]
#  [5.4 3.  4.5 1.5]
#  [6.7 3.  5.  1.7]
#  [5.9 3.2 4.8 1.8]
#  [5.1 2.5 3.  1.1]
#  [6.  2.7 5.1 1.6]
#  [6.3 2.5 4.9 1.5]
#  [6.1 2.9 4.7 1.4]
#  [6.5 2.8 4.6 1.5]
#  [6.9 3.1 4.9 1.5]
#  [6.3 2.3 4.4 1.3]
#  [6.3 2.8 5.1 1.5]
#  [6.3 2.7 4.9 1.8]
#  [6.  3.  4.8 1.8]
#  [6.  2.2 5.  1.5]
#  [6.2 2.8 4.8 1.8]
#  [6.5 3.  5.2 2. ]
#  [7.2 3.  5.8 1.6]
#  [5.6 2.8 4.9 2. ]
#  [5.9 3.  5.1 1.8]
#  [4.9 2.5 4.5 1.7]]

# %%
# 7.  Write a Python program to:
#● Load the Breast Cancer dataset
#● Train a Gaussian Naïve Bayes model
#● Print its classification report including precision, recall, and F1-score.


# Import necessary libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report

# Load the Breast Cancer dataset
data = load_breast_cancer()
X = data.data      # Features
y = data.target    # Labels (0 = malignant, 1 = benign)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train a Gaussian Naïve Bayes model
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# Predict on the test set
y_pred = gnb.predict(X_test)

# Print classification report
print("Gaussian Naïve Bayes Classifier - Breast Cancer Dataset")
print(classification_report(y_test, y_pred, target_names=data.target_names))
# Out:
# Gaussian Naïve Bayes Classifier - Breast Cancer Dataset
#               precision    recall  f1-score   support
#
#    malignant       0.93      0.90      0.92        63
#       benign       0.95      0.96      0.95       108
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.93      0.94       171
# weighted avg       0.94      0.94      0.94       171

# %%
# 8. Write a Python program to:
#● Train an SVM Classifier on the Wine dataset using GridSearchCV to find the best
#C and gamma.
#● Print the best hyperparameters and accuracy.

# Import necessary libraries
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Load the dataset
data = load_wine()
X, y = data.data, data.target

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Define parameter grid for C and gamma
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [0.001, 0.01, 0.1, 1],
    'kernel': ['rbf']
}

# Initialize SVM classifier
svm = SVC()

# Initialize GridSearchCV
grid_search = GridSearchCV(svm, param_grid, cv=5, scoring='accuracy')

# Train the model
grid_search.fit(X_train, y_train)

# Get best model
best_model = grid_search.best_estimator_

# Predict on test set
y_pred = best_model.predict(X_test)

# Print best parameters and accuracy
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Accuracy: {:.4f}".format(grid_search.best_score_))
print("Test Accuracy: {:.4f}".format(accuracy_score(y_test, y_pred)))
# Out:
# Best Parameters: {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# Best Cross-Validation Accuracy: 0.7340
# Test Accuracy: 0.7778

# %%
# 9. Write a Python program to:
#● Train a Naïve Bayes Classifier on a synthetic text dataset (e.g. using
#sklearn.datasets.fetch_20newsgroups).
#● Print the model's ROC-AUC score for its predictions.

# Import libraries
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

# Load dataset (binary classification: two categories)
categories = ['alt.atheism', 'sci.space']  # Example: binary task
newsgroups = fetch_20newsgroups(subset='all', categories=categories)

X, y = newsgroups.data, newsgroups.target

# Convert text to TF-IDF features
vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)
X_tfidf = vectorizer.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf, y, test_size=0.3, random_state=42, stratify=y
)

# Train Naïve Bayes classifier
nb = MultinomialNB()
nb.fit(X_train, y_train)

# Predict probabilities
y_proba = nb.predict_proba(X_test)[:, 1]

# Compute ROC-AUC
roc_auc = roc_auc_score(y_test, y_proba)
print("ROC-AUC Score: {:.4f}".format(roc_auc))
# Out:
# ROC-AUC Score: 0.9992

# %% [markdown]
# 10. Imagine you’re working as a data scientist for a company that handles
# email communications.
# Your task is to automatically classify emails as Spam or Not Spam. The emails may
# contain:
#
# ● Text with diverse vocabulary
#
# ● Potential class imbalance (far more legitimate emails than spam)
#
# ● Some incomplete or missing data
#
# Explain the approach you would take to:
#
# ● Preprocess the data (e.g. text vectorization, handling missing data)
#
# ● Choose and justify an appropriate model (SVM vs. Naïve Bayes)
#
# ● Address class imbalance
#
# ● Evaluate the performance of your solution with suitable metrics
#
# And explain the business impact of your solution.
#
# Ans:1. Preprocessing the Data
#
# ---Handling Missing Data
#
#  - Emails may have missing fields (e.g., empty subject/body).
#
#  - Strategy: replace missing text with placeholders like "missing" so the model can still process.
#
# ---Text Vectorization
#
#  - Convert email text into numerical features:
#
#  - TF-IDF (Term Frequency–Inverse Document Frequency): balances frequent/common words (like “the”, “and”) vs. discriminative words (“lottery”, “win”).
#
#  - Optionally: n-grams (bi-grams/trigrams) to capture short phrases like “free money”.
#
#  - Feature Engineering (optional)
#
# Length of email, number of links, number of special characters, presence of spammy words (“winner”, “prize”).
#
# Can be combined with text features.
#
# 2. Choosing the Model: SVM vs. Naïve Bayes
#
#  - Naïve Bayes (Multinomial NB)
#
# Works very well with text because it assumes word independence.
#
# Fast to train, low computational cost, handles high-dimensional sparse data well.
#
#  - SVM (Support Vector Machine)
#
# Strong for high-dimensional spaces, finds optimal separating hyperplane.
#
# Tends to perform slightly better than Naïve Bayes when data is well-balanced and not extremely large.
#
# But more computationally expensive on very large datasets.
#
# -  Practical Choice: Start with Multinomial Naïve Bayes as a baseline (fast, interpretable).
# If dataset is large and you need higher precision (e.g., avoid false positives on legit emails), SVM with linear kernel can be used.
#
# 3. Handling Class Imbalance
#
#  - Spam detection datasets usually have many more ham (legit) emails than spam.
#
# Solutions:
#
#  - Resampling techniques:
#
# Oversample minority class (spam) using SMOTE.
#
# Undersample majority class (not spam).
#
#  - Class Weights:
#
# In SVM, set class_weight='balanced'.
#
#  - Threshold tuning:
#
# Adjust decision threshold to favor recall (catch more spam) or precision (avoid flagging legit emails as spam) depending on business need.
#
# 4. Evaluation Metrics
#
#  - Accuracy alone is misleading with imbalance (e.g., 95% ham, 5% spam → a dumb model predicting “Not Spam” gets 95%).
# So we use:
#
#  - Precision: of predicted spam, how many are actually spam? (important to avoid flagging real emails).
#
#  - Recall: of actual spam, how many did we catch? (important to minimize spam leakage).
#
#  - F1-score: balances precision & recall.
#
#  - ROC-AUC: measures model’s ability to rank spam higher than ham.
#
#  - Confusion Matrix: to see types of errors (false positives vs false negatives).
#
# 5. Business Impact
#
#  - Positive:
#
# Reduced manual filtering → saves employee/customer time.
#
# Protects against phishing/malicious links → prevents security breaches.
#
# Enhances customer trust → fewer spam emails reaching inbox.
#
#  - Risks:
#
# Too many false positives (legit emails flagged as spam) → missed opportunities, unhappy users.
#
# Too many false negatives (spam not caught) → lower trust.
#
# -  The model must balance precision vs recall depending on company goals. For a bank, recall (catch all spam/phishing) is critical. For a customer email service, precision (don’t block real mail) may be more important.
#
#
# summary:
#
#  - Preprocess: TF-IDF + missing data handling
#
#  - Model: Start with Naïve Bayes, compare with SVM (linear kernel)
#
#  - Handle imbalance with class weights or resampling
#
#  - Evaluate using precision, recall, F1, ROC-AUC
#
#  - Business impact: Improved efficiency, security, and user satisfaction.
